# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# # Thông tin sinh viên

# %% [markdown]
# Họ tên: Phan Anh Lộc
#
# MSSV: 19521766
#
# Bài thực hành số 6

# %% [markdown]
# # Import các thư viện

# %%
import cv2
from scipy import ndimage
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # Đường dẫn môn học

# %%
dir_monhoc = '/gdrive/MyDrive/CS231.M12.KHCL'
dir_baitap = os.path.join(dir_monhoc, 'Baitap','Baitap6')
dir_img = os.path.join(dir_baitap, 'images')

# %%
cow1 = os.path.join(dir_img, 'cow1.jpg')
cow2 = os.path.join(dir_img, 'cow2.jpg')

match1 = os.path.join(dir_img, 'match1.jpg')
match2 = os.path.join(dir_img, 'match2.jpg')

graf1 = os.path.join(dir_img, 'graf_img1.jpg')
graf2 = os.path.join(dir_img, 'graf_img5.jpg')

# %% [markdown]
# # Corner harris

# %%
def harris_corner(filename):
  img = cv2.imread(filename)
  gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
  gray = np.float32(gray)
  dst = cv2.cornerHarris(gray,2,3,0.04)
  dst = cv2.dilate(dst,None)
  img[dst>0.01*dst.max()]=[0,0,255]
  cv2_imshow(img)

# %%
harris_corner(cow1)
harris_corner(cow2)
# Out:
# <PIL.Image.Image image mode=RGB size=436x554 at 0x7FE060100B50>
# <PIL.Image.Image image mode=RGB size=420x553 at 0x7FE0601007D0>

# %%
harris_corner(match1)
harris_corner(match2)
# Out:
# <PIL.Image.Image image mode=RGB size=690x499 at 0x7FE05EFB0990>
# <PIL.Image.Image image mode=RGB size=690x499 at 0x7FE05EFB0690>

# %%
harris_corner(graf1)
harris_corner(graf2)
# Out:
# <PIL.Image.Image image mode=RGB size=640x512 at 0x7FE05EF3BC10>
# <PIL.Image.Image image mode=RGB size=640x512 at 0x7FE05EF3B390>
